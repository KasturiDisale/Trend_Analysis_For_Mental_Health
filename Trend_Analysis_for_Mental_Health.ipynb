# %% [markdown]
# <a href="https://colab.research.google.com/github/KasturiDisale/Trend_Analysis_For_Mental_Health/blob/main/Trend_Analysis_for_Mental_Health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# load dataset
df = pd.read_csv("./joined_HPMD.csv")
df.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  ...  \
# 0                      0.718114    0.167652                   0.881686  ...
# 1                      0.678896    0.190809                   0.850035  ...
# 2                      0.600127    0.121316                   0.706766  ...
# 3                      0.495901    0.163571                   0.731109  ...
# 4                      0.530935    0.237588                   0.775620  ...
#
#    Confidence In National Government  index  Code  Schizophrenia  \
# 0                           0.612072     18   AFG       0.164639
# 1                           0.611545     19   AFG       0.164932
# 2                           0.299357     20   AFG       0.165130
# 3                           0.307386     21   AFG       0.165272
# 4                           0.435440     22   AFG       0.165424
#
#   Bipolar disorders  Eating disorders  Anxiety disorders  Drug use disorders  \
# 0          0.704480          0.093589           4.860437            2.483862
# 1          0.704925          0.095166           4.861533            2.543884
# 2          0.705313          0.097327           4.862777            2.571349
# 3          0.705688          0.098638           4.864773            2.573170
# 4          0.706086          0.099891           4.867283            2.576189
#
#    Depression  Alcohol use disorders
# 0    4.129656               0.659501
# 1    4.129972               0.661185
# 2    4.130874               0.662062
# 3    4.130862               0.662254
# 4    4.132485               0.662372
#
# [5 rows x 22 columns]

# %%
sum_by_year = df.groupby('Year').size()
sum_by_year
# Out:
# Year
# 2005      1
# 2006     71
# 2007     85
# 2008     94
# 2009     86
# 2010     94
# 2011    108
# 2012    105
# 2013    110
# 2014    115
# 2015    117
# 2016    115
# 2017    120
# dtype: int64

# %%
# drop 2005 data
df =  df[df['Year'] != 2005]
sum_by_year = df.groupby('Year').size()
sum_by_year
# Out:
# Year
# 2006     71
# 2007     85
# 2008     94
# 2009     86
# 2010     94
# 2011    108
# 2012    105
# 2013    110
# 2014    115
# 2015    117
# 2016    115
# 2017    120
# dtype: int64

# %%
# How many rows does each country have?

sum_by_country = df.groupby('Country Name').size()
sum_by_country
# Out:
# Country Name
# Afghanistan    10
# Albania         7
# Argentina      12
# Armenia        12
# Australia      10
#                ..
# Venezuela      11
# Vietnam         6
# Yemen           7
# Zambia         11
# Zimbabwe       12
# Length: 129, dtype: int64

# %%
# Life Ladder, 2005~2017
fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(data=df, x='Year', y='Life Ladder', fill=False)
sns.stripplot(data=df, x='Year', y='Life Ladder', hue='Regional Indicator')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Year')
plt.ylabel('Life Ladder')
plt.show()

# %%
import pandas as pd

# Assuming your dataset is stored in a DataFrame called df
# Example DataFrame structure
df_test = pd.DataFrame({'year': [2021, 2021, 2021], 'country': ['USA', 'India', 'Brazil'], 'gdp': [60000, 2500, 12000]})

# Calculate the quantiles for the GDP column
gdp_25 = df_test['gdp'].quantile(0.25)
gdp_50 = df_test['gdp'].quantile(0.50)
gdp_75 = df_test['gdp'].quantile(0.75)

# Define a function to assign GDP level based on the quantiles
def gdp_level(gdp):
    if gdp > gdp_75:
        return 'high'
    elif gdp_50 < gdp <= gdp_75:
        return 'higher-middle'
    elif gdp_25 < gdp <= gdp_50:
        return 'lower-middle'
    else:
        return 'low'

# Apply the function to create the 'gdp level' column
df_test['gdp level'] = df_test['gdp'].apply(gdp_level)

# Display the updated DataFrame
print(df_test)
# Out:
#    year country    gdp     gdp level
# 0  2021     USA  60000          high
# 1  2021   India   2500           low
# 2  2021  Brazil  12000  lower-middle

# %%
gdp_25 = df['Log GDP Per Capita'].quantile(0.25)
gdp_50 = df['Log GDP Per Capita'].quantile(0.50)
gdp_75 = df['Log GDP Per Capita'].quantile(0.75)

def gdp_level(gdp):
    if gdp > gdp_75:
        return 'high'
    elif gdp_50 < gdp <= gdp_75:
        return 'higher-middle'
    elif gdp_25 < gdp <= gdp_50:
        return 'lower-middle'
    else:
        return 'low'

df['gdp_level'] = df['Log GDP Per Capita'].apply(gdp_level)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1220 entries, 0 to 1220
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country Name                       1220 non-null   object
#  1   Regional Indicator                 1220 non-null   object
#  2   Year                               1220 non-null   int64
#  3   Life Ladder                        1220 non-null   float64
#  4   Log GDP Per Capita                 1220 non-null   float64
#  5   Social Support                     1220 non-null   float64
#  6   Healthy Life Expectancy At Birth   1220 non-null   float64
#  7   Freedom To Make Life Choices       1220 non-null   float64
#  8   Generosity                         1220 non-null   float64
#  9   Perceptions Of Corruption          1220 non-null   float64
#  10  Positive Affect                    1220 non-null   float64
#  11  Negative Affect                    1220 non-null   float64
#  12  Confidence In National Government  1220 non-null   float64
#  13  index                              1220 non-null   int64
#  14  Code                               1220 non-null   object
#  15  Schizophrenia                      1220 non-null   float64
#  16  Bipolar disorders                  1220 non-null   float64
#  17  Eating disorders                   1220 non-null   float64
#  18  Anxiety disorders                  1220 non-null   float64
#  19  Drug use disorders                 1220 non-null   float64
#  20  Depression                         1220 non-null   float64
#  21  Alcohol use disorders              1220 non-null   float64
#  22  gdp_level                          1220 non-null   object
# dtypes: float64(17), int64(2), object(4)
# memory usage: 228.8+ KB

# %%
import plotly.express as px

x = df['Life Ladder']
y = df['Log GDP Per Capita']
country = df['Country Name']

fig = px.scatter(
    df,x, y,
    color="gdp_level",
    hover_data=['Country Name', 'Year', 'gdp_level'],
    color_discrete_sequence=["#a6cc70", '#695649', '#E59500', '#348AA7'],
    title="World Happiness, 2005~2021, by GDP level.",
    labels = {'gdp_level':"GDP level"}
    )
fig.update_traces(
     marker = dict(size=8,line = dict(width=0.3,color='white')),
     selector = dict(mode='markers'),
     hovertemplate = (
      "<b>%{customdata[0]}</b>, %{customdata[1]} <br>"
      "<b>Life Ladder:</b> %{x:.2f}</br>"
      "<b>Log GDP Per Capita:</b> %{y:.2f} (%{customdata[2]})</br>"
      "<extra></extra>"
     ),

)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3744e63e-8aec-4708-9043-72ff55af23ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3744e63e-8aec-4708-9043-72ff55af23ce")) {                    Plotly.newPlot(                        "3744e63e-8aec-4708-9043-72ff55af23ce",                        [{"customdata":[["Afghanistan",2008,"low"],["Afghanistan",2009,"low"],["Afghanistan",2010,"low"],["Afghanistan",2011,"low"],["Afghanistan",2012,"low"],["Afghanistan",2013,"low"],["Afghanistan",2014,"low"],["Afghanistan",2015,"low"],["Afghanistan",2016,"low"],["Afghanistan",2017,"low"],["Bangladesh",2006,"low"],["Bangladesh",2007,"low"],["Bangladesh",2008,"low"],["Bangladesh",2009,"low"],["Bangladesh",2010,"low"],["Bangladesh",2011,"low"],["Bangladesh",2012,"low"],["Bangladesh",2013,"low"],["Benin",2006,"low"],["Benin",2008,"low"],["Benin",2011,"low"],["Benin",2012,"low"],["Benin",2013,"low"],["Benin",2014,"low"],["Benin",2015,"low"],["Benin",2016,"low"],["Benin",2017,"low"],["Burkina Faso",2006,"low"],["Burkina Faso",2007,"low"],["Burkina Faso",2008,"low"],["Burkina Faso",2010,"low"],["Burkina Faso",2011,"low"],["Burkina Faso",2012,"low"],["Burkina Faso",2013,"low"],["Burkina Faso",2014,"low"],["Burkina Faso",2015,"low"],["Burkina Faso",2016,"low"],["Burkina Faso",2017,"low"],["Burundi",2008,"low"],["Burundi",2009,"low"],["Burundi",2011,"low"],["Cambodia",2008,"low"],["Cambodia",2009,"low"],["Cambodia",2010,"low"],["Cambodia",2011,"low"],["Cambodia",2012,"low"],["Cambodia",2013,"low"],["Cambodia",2014,"low"],["Cambodia",2015,"low"],["Cambodia",2016,"low"],["Cambodia",2017,"low"],["Cameroon",2006,"low"],["Cameroon",2007,"low"],["Cameroon",2008,"low"],["Cameroon",2009,"low"],["Cameroon",2010,"low"],["Cameroon",2011,"low"],["Cameroon",2012,"low"],["Cameroon",2013,"low"],["Cameroon",2014,"low"],["Cameroon",2015,"low"],["Cameroon",2016,"low"],["Cameroon",2017,"low"],["Chad",2006,"low"],["Chad",2007,"low"],["Chad",2008,"low"],["Chad",2009,"low"],["Chad",2010,"low"],["Chad",2011,"low"],["Chad",2012,"low"],["Chad",2013,"low"],["Chad",2014,"low"],["Chad",2015,"low"],["Chad",2016,"low"],["Chad",2017,"low"],["Comoros",2009,"low"],["Comoros",2010,"low"],["Comoros",2011,"low"],["Comoros",2012,"low"],["Ethiopia",2013,"low"],["Ethiopia",2014,"low"],["Ethiopia",2015,"low"],["Ethiopia",2016,"low"],["Ethiopia",2017,"low"],["Gambia",2017,"low"],["Ghana",2006,"low"],["Ghana",2007,"low"],["Ghana",2008,"low"],["Ghana",2009,"low"],["Ghana",2010,"low"],["Ghana",2011,"low"],["Guinea",2011,"low"],["Guinea",2012,"low"],["Guinea",2013,"low"],["Guinea",2014,"low"],["Guinea",2015,"low"],["Guinea",2016,"low"],["Guinea",2017,"low"],["Haiti",2006,"low"],["Haiti",2008,"low"],["Haiti",2010,"low"],["Haiti",2011,"low"],["Haiti",2012,"low"],["Haiti",2013,"low"],["Haiti",2014,"low"],["Haiti",2015,"low"],["Haiti",2016,"low"],["Haiti",2017,"low"],["India",2007,"low"],["India",2008,"low"],["India",2009,"low"],["Kenya",2006,"low"],["Kenya",2007,"low"],["Kenya",2008,"low"],["Kenya",2009,"low"],["Kenya",2010,"low"],["Kenya",2011,"low"],["Kenya",2012,"low"],["Kenya",2013,"low"],["Kenya",2014,"low"],["Kyrgyzstan",2006,"low"],["Kyrgyzstan",2007,"low"],["Kyrgyzstan",2008,"low"],["Kyrgyzstan",2010,"low"],["Laos",2006,"low"],["Laos",2007,"low"],["Lesotho",2011,"low"],["Lesotho",2016,"low"],["Lesotho",2017,"low"],["Liberia",2007,"low"],["Liberia",2008,"low"],["Liberia",2010,"low"],["Liberia",2014,"low"],["Liberia",2015,"low"],["Liberia",2016,"low"],["Liberia",2017,"low"],["Madagascar",2008,"low"],["Madagascar",2011,"low"],["Madagascar",2012,"low"],["Madagascar",2013,"low"],["Madagascar",2014,"low"],["Madagascar",2015,"low"],["Madagascar",2016,"low"],["Madagascar",2017,"low"],["Malawi",2006,"low"],["Malawi",2007,"low"],["Malaw ...

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 15))
sns.boxplot(data=df, x='Year', y='Life Ladder', fill=False, ax = axes[0,0], legend=False)
sns.stripplot(data=df, x='Year', y='Life Ladder', hue='gdp_level', ax = axes[0,0],legend=False)

sns.boxplot(data=df, x='Year', y='Schizophrenia', fill=False, ax = axes[0,1], legend=False)
sns.stripplot(data=df, x='Year', y='Schizophrenia', hue='gdp_level', ax = axes[0,1], legend=False)

sns.boxplot(data=df, x='Year', y='Bipolar disorders', fill=False, ax = axes[1,0], legend=False)
sns.stripplot(data=df, x='Year', y='Bipolar disorders', hue='gdp_level', ax = axes[1,0], legend=False)

sns.boxplot(data=df, x='Year', y='Eating disorders', fill=False, ax = axes[2,0], legend=False)
sns.stripplot(data=df, x='Year', y='Eating disorders', hue='gdp_level', ax = axes[2,0], legend=False)

sns.boxplot(data=df, x='Year', y='Anxiety disorders', fill=False, ax = axes[3,0], legend=False)
sns.stripplot(data=df, x='Year', y='Anxiety disorders', hue='gdp_level', ax = axes[3,0], legend=False)

sns.boxplot(data=df, x='Year', y='Drug use disorders', fill=False, ax = axes[1,1], legend=False)
sns.stripplot(data=df, x='Year', y='Drug use disorders', hue='gdp_level', ax = axes[1,1], legend=False)


sns.boxplot(data=df, x='Year', y='Depression', fill=False, ax = axes[2,1], legend=False)
sns.stripplot(data=df, x='Year', y='Depression', hue='gdp_level', ax = axes[2,1], legend=False)

sns.boxplot(data=df, x='Year', y='Alcohol use disorders', fill=False, ax = axes[3,1], legend=False)
sns.stripplot(data=df, x='Year', y='Alcohol use disorders', hue='gdp_level', ax = axes[3,1])


plt.tight_layout()
plt.show()

# %%
# add a column that shows the average of the disorder, from 2006~2017

disorders = [
    "Schizophrenia", "Bipolar disorders", "Eating disorders",
    "Anxiety disorders", "Drug use disorders",
    "Depression", "Alcohol use disorders"
]

avg_percentage = df.groupby("Country Name")[disorders].mean()
# df.head()
# print(avg_percentage)

avg_disorder_df = pd.DataFrame(avg_percentage)
avg_disorder_df = avg_disorder_df.reset_index()
# avg_disorder_df.info()

# %%
# merge gdp_level with avg_disorder_df

df_aggregated = df.groupby('Country Name', as_index=False).agg({'gdp_level':'first'})
merged_df = pd.merge(avg_disorder_df, df_aggregated, on=['Country Name'], how='left')
avg_disorder_df = merged_df

# %%
import plotly.graph_objects as go
import pycountry

def get_country_code(country_name):
    try:
        return pycountry.countries.lookup(country_name).alpha_3
    except LookupError:
        return None

avg_disorder_df['Country Code'] = avg_disorder_df['Country Name'].apply(get_country_code)
avg_disorder_df = avg_disorder_df.dropna(subset=['Country Code'])

fig = go.Figure()

# Add traces for each indicator
for disorder in disorders:
    fig.add_trace(go.Choropleth(
        locations=avg_disorder_df['Country Code'],
        locationmode='ISO-3',
        z=avg_disorder_df[disorder],
        customdata=avg_disorder_df['gdp_level'],
        hovertext=avg_disorder_df['Country Name'],
        hovertemplate='%{hovertext}: %{z:.2f}%<extra></extra> <br>GDP level: %{customdata}',
        name=disorder,
        visible=False,
        colorscale= 'YlGnBu'

    ))

# Set the first indicator trace to be visible by default
fig.data[0].visible = True

# Create dropdown buttons
dropdown_buttons = [
    {
        'label': disorder,
        'method': 'update',
        'args': [
            {'visible': [disorder == ind for ind in disorders]},
            {'title': f"{disorder} Average Percentage (2006~2017)"}
        ]
    }
    for disorder in disorders
]

# Update layout with dropdown
fig.update_layout(
    updatemenus=[dict(
            buttons=dropdown_buttons,
            direction="down",
            showactive=True,
            x=1,
            y=1.15,
            xanchor="right",
            yanchor="top"
        )],
    geo=dict(
        showframe=False,
        showcoastlines=True,
        projection_type='equirectangular'
    ),
    title= f'{disorders[0]} Average Percentage (2006~2017)'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba396eef-e7a2-4ede-bf1e-15afd75a5837" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba396eef-e7a2-4ede-bf1e-15afd75a5837")) {                    Plotly.newPlot(                        "ba396eef-e7a2-4ede-bf1e-15afd75a5837",                        [{"colorscale":[[0.0,"rgb(255,255,217)"],[0.125,"rgb(237,248,177)"],[0.25,"rgb(199,233,180)"],[0.375,"rgb(127,205,187)"],[0.5,"rgb(65,182,196)"],[0.625,"rgb(29,145,192)"],[0.75,"rgb(34,94,168)"],[0.875,"rgb(37,52,148)"],[1.0,"rgb(8,29,88)"]],"customdata":["low","lower-middle","higher-middle","lower-middle","high","high","lower-middle","low","higher-middle","high","low","lower-middle","lower-middle","higher-middle","higher-middle","higher-middle","low","low","low","low","high","low","higher-middle","lower-middle","low","higher-middle","higher-middle","high","high","lower-middle","lower-middle","lower-middle","lower-middle","high","low","high","high","higher-middle","low","lower-middle","high","low","high","lower-middle","low","low","lower-middle","higher-middle","high","low","lower-middle","higher-middle","lower-middle","high","high","high","lower-middle","high","higher-middle","low","high","low","low","higher-middle","higher-middle","low","low","higher-middle","high","low","low","higher-middle","low","high","lower-middle","higher-middle","higher-middle","lower-middle","lower-middle","higher-middle","lower-middle","low","low","lower-middle","low","high","high","lower-middle","low","low","high","low","higher-middle","lower-middle","lower-middle","lower-middle","higher-middle","high","higher-middle","low","low","higher-middle","low","high","higher-middle","high","higher-middle","high","high","lower-middle","high","high","low","low","lower-middle","low","lower-middle","low","lower-middle","high","high","higher-middle","low","higher-middle","lower-middle","low","low","low"],"hovertemplate":"%{hovertext}: %{z:.2f}%\u003cextra\u003e\u003c\u002fextra\u003e \u003cbr\u003eGDP level: %{customdata}","hovertext":["Afghanistan","Albania","Argentina","Armenia","Australia","Austria","Azerbaijan","Bangladesh","Belarus","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Chad","Chile","Colombia","Comoros","Costa Rica","Croatia","Cyprus","Denmark","Dominican Republic","Ecuador","Egypt","El Salvador","Estonia","Ethiopia","Finland","France","Gabon","Gambia","Georgia","Germany","Ghana","Greece","Guatemala","Guinea","Haiti","Honduras","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Israel","Italy","Jamaica","Japan","Kazakhstan","Kenya","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Lithuania","Luxembourg","Madagascar","Malawi","Malaysia","Mali","Malta","Mauritania","Mauritius","Mexico","Moldova","Mongolia","Montenegro","Morocco","Mozambique","Myanmar","Namibia","Nepal","Netherlands","New Zealand","Nicaragua","Niger","Nigeria","Norway","Pakistan","Panama","Paraguay","Peru","Philippines","Poland","Portugal","Romania","Rwanda","Senegal","Serbia","Sierra Leone","Singapore","Slovakia","Slovenia","South Africa","South Korea","Spain","Sri Lanka","Sweden","Switzerland","Tajikistan","Tanzania","Thailand","Togo","Tunisia","Uganda","Ukraine","United Kingdom","United States","Uruguay","Uzbekistan","Venezuela","Vietnam","Yemen","Zambia","Zimbabwe"],"locationmode":"ISO-3","locations":["AFG","ALB","ARG","ARM","AUS","AUT","AZE","BGD","BLR","BEL","BEN","BOL","BIH","BWA","BRA","BGR","BFA","BDI","KHM","CMR","CAN","TCD","CHL","COL","COM","CRI","HRV","CYP","DNK","DOM","ECU","EGY","SLV","EST","ETH","FIN","FRA","GAB","GMB","GEO","DEU","GHA","GRC","GTM","GIN","HTI","HND","HUN","ISL","IND","IDN", ...
